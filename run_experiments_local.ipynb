# %% [markdown]
# Notebook to run experiments locally

# %%
from src.dataset import KreuzerSkarkeDataset
dataset = KreuzerSkarkeDataset(load_projections=True, projections_file='original')
# Out:
# Loading projection from /home/daniel/PycharmProjects/kreuzer-skarke-ML/data/projections/original.npz ...
# ...finished loading

# %%
from src.models.vanilla_nn import Vanilla_nn
from src.models.hartford import Hartford
from src.models.invariantmlp import InvariantMLP
from src.models.xgboost import XGboost
from src.models.vision_transformer import VisionT
MODELS = [
    Vanilla_nn,
    Hartford,
    InvariantMLP,
    XGboost,
    #VisionT
    ]

# %%
all_accuracies = []
for model in MODELS:
    model_instance = model(dataset)
    model_instance.train(num_epochs=1)
    this_acc = model_instance.get_accuracy()
    print(f'This accuracy: {this_acc}')
    all_accuracies += [this_acc]

print(f'All accuracies: {all_accuracies}')
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 4, 26, 1)]        0
#
#  conv2d_12 (Conv2D)          (None, 3, 25, 5)          25
#
#  conv2d_13 (Conv2D)          (None, 2, 24, 4)          84
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense_5 (Dense)             (None, 64)                12352
#
#  dense_6 (Dense)             (None, 50)                3250
#
#  dense_7 (Dense)             (None, 1)                 51
#
# ...
# Total params: 15,762
# Trainable params: 15,762
# Non-trainable params: 0
# _________________________________________________________________
# None
# 62772/62772 [==============================] - 53s 836us/step - loss: 4.1471 - soft_acc: 0.2061 - mean_squared_error: 4.1471 - val_loss: 2.8742 - val_soft_acc: 0.2372 - val_mean_squared_error: 2.8742
# ...
