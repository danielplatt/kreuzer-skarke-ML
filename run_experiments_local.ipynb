# %% [markdown]
# Notebook to run experiments locally

# %%
from src.dataset import KreuzerSkarkeDataset
dataset = KreuzerSkarkeDataset(load_projections=True, projections_file='original')
# Out:
# Loading projection from /home/daniel/PycharmProjects/kreuzer-skarke-ML/data/projections/original.npz ...
# ...finished loading

# %%
from src.models.vanilla_nn import Vanilla_nn
from src.models.hartford import Hartford
from src.models.invariantmlp import InvariantMLP
from src.models.xgboost import XGboost
from src.models.vision_transformer import VisionT
MODELS = [Vanilla_nn, Hartford, InvariantMLP, XGboost, VisionT]

# %%
all_accuracies = []
for model in MODELS:
    model_instance = model(dataset)
    model_instance.train(num_epochs=1)
    model_instance.get_accuracy()

print(f'All accuracies: {all_accuracies}')
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 4, 26, 1)]        0
#
#  conv2d_16 (Conv2D)          (None, 3, 25, 5)          25
#
#  conv2d_17 (Conv2D)          (None, 2, 24, 4)          84
#
#  flatten_2 (Flatten)         (None, 192)               0
#
#  dense_11 (Dense)            (None, 64)                12352
#
#  dense_12 (Dense)            (None, 50)                3250
#
#  dense_13 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 15,762
# Trainable params: 15,762
# Non-trainable params: 0
# _________________________________________________________________
# None
# 62772/62772 [==============================] - 102s 2ms/step - loss: 4.2354 - soft_acc: 0.2003 - mean_squared_error: 4.2354 - val_loss: 2.7783 - val_soft_acc: 0.2407 - val_mean_squared_error: 2.7783
# Saving final model checkpoint to /home/daniel/PycharmProjects/kreuzer-skarke-ML/data/saved_models/vanilla_nn_original.h5 for 1 epochs
# Saving results as a csv in  /home/daniel/PycharmProjects/kreuzer-skarke-ML/data/saved_results/vanilla_nn_original.csv
# 123/123 [==============================] - 0s 2ms/step - loss: 2.7784 - soft_acc: 0.2407 - mean_squared_error: 2.7784
# Evaluating on 128 batch size [2.778355836868286, 0.24073801934719086, 2.778355836868286]
# 491/491 [==============================] - 1s 1ms/step
# The accuracy on the test set is  0.2407289409965592
# None
# 123/123 [==============================] - 0s 1ms/step - loss: 2.7784 - soft_acc: 0.2407 - mean_squared_error: 2.7784
# Evaluating on 128 batch size [2.778355836868286, 0.24073801934719086, 2.778355836868286]
# 491/491 [==============================] - 1s 1ms/step
# The accuracy on the test set is  0.2407289409965592
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 4, 26, 1)]   0           []
#
#  concatenate_13 (Concatenate)   (None, 4, 26, 256)   0           ['input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]',
#                                                                   'input_8[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 1, 1, 256)   0           ['concatenate_13[0][0]']
#  ooling2D)
#
#  average_pooling2d_9 (AveragePo  (None, 4, 1, 256)   0           ['concatenate_13[0][0]']
#  oling2D)
#
#  average_pooling2d_10 (AverageP  (None, 1, 26, 256)  0           ['concatenate_13[0][0]']
#  ooling2D)
#
#  concatenate_16 (Concatenate)   (None, 4, 1, 256)    0           ['average_pooling2d_11[0][0]',
#                                                                   'average_pooling2d_11[0][0]',
#                                                                   'average_pooling2d_11[0][0]',
#                                                                   'average_pooling2d_11[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 4, 26, 256)   0           ['average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]',
#                                                                   'average_pooling2d_9[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 4, 26, 256)   0           ['average_pooling2d_10[0][0]',
#                                                                   'average_pooling2d_10[0][0]',
#                                                                   'average_pooling2d_10[0][0]',
#                                                                   'average_pooling2d_10[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 4, 26, 256)   0           ['concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]',
#                                                                   'concatenate_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 4, 26, 256)   65536       ['concatenate_13[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 4, 26, 256)   65536       ['concatenate_14[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 4, 26, 256)   65536       ['concatenate_15[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 4, 26, 256)   65792       ['concatenate_17[0][0]']
#
#  add_3 (Add)                    (None, 4, 26, 256)   0           ['conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 1, 1, 256)   0           ['add_3[0][0]']
#  ooling2D)
#
#  average_pooling2d_12 (AverageP  (None, 4, 1, 256)   0           ['add_3[0][0]']
#  ooling2D)
#
#  average_pooling2d_13 (AverageP  (None, 1, 26, 256)  0           ['add_3[0][0]']
#  ooling2D)
#
#  concatenate_20 (Concatenate)   (None, 4, 1, 256)    0           ['average_pooling2d_14[0][0]',
#                                                                   'average_pooling2d_14[0][0]',
#                                                                   'average_pooling2d_14[0][0]',
#                                                                   'average_pooling2d_14[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 4, 26, 256)   0           ['average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]',
#                                                                   'average_pooling2d_12[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 4, 26, 256)   0           ['average_pooling2d_13[0][0]',
#                                                                   'average_pooling2d_13[0][0]',
#                                                                   'average_pooling2d_13[0][0]',
#                                                                   'average_pooling2d_13[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 4, 26, 256)   0           ['concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'concatenate_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 4, 26, 256)   65536       ['add_3[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 4, 26, 256)   65536       ['concatenate_18[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 4, 26, 256)   65536       ['concatenate_19[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 4, 26, 256)   65792       ['concatenate_21[0][0]']
#
#  add_4 (Add)                    (None, 4, 26, 256)   0           ['conv2d_22[0][0]',
#                                                                   'conv2d_23[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  average_pooling2d_17 (AverageP  (None, 1, 1, 256)   0           ['add_4[0][0]']
#  ooling2D)
#
#  average_pooling2d_15 (AverageP  (None, 4, 1, 256)   0           ['add_4[0][0]']
#  ooling2D)
#
#  average_pooling2d_16 (AverageP  (None, 1, 26, 256)  0           ['add_4[0][0]']
#  ooling2D)
#
#  concatenate_24 (Concatenate)   (None, 4, 1, 256)    0           ['average_pooling2d_17[0][0]',
#                                                                   'average_pooling2d_17[0][0]',
#                                                                   'average_pooling2d_17[0][0]',
#                                                                   'average_pooling2d_17[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 4, 26, 256)   0           ['average_pooling2d_15[0][0]',
#                                                                   'average_pooling2d_15[0][0]',
#                                                                   'average_pooling2d_15[0][0]',
#                                                                   'average_pooling2d_15[0][0]',
#                                                                   'average_pooling2d_15[0][0]',
#                                                                   'average_pooling2d_15[0][0]',
#                                                                   'average_pooling2d_15[0][0]',
#                                                                   'average_pooling2d_15[0][0]',
#                                                                   'average_pooling2d_15[0][0]',
#                                                                   'average_pooling2d_15[0][0]',
#                                                                   'average_pooling2d_15[0][0]',
#                                                                   'average_pooling2d_15[0][0]',
# ...
#                                                                   'average_pooling2d_16[0][0]',
#                                                                   'average_pooling2d_16[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 4, 26, 256)   0           ['concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]',
#                                                                   'concatenate_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 4, 26, 256)   65536       ['add_4[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 4, 26, 256)   65536       ['concatenate_22[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 4, 26, 256)   65536       ['concatenate_23[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 4, 26, 256)   65792       ['concatenate_25[0][0]']
#
#  add_5 (Add)                    (None, 4, 26, 256)   0           ['conv2d_26[0][0]',
#                                                                   'conv2d_27[0][0]',
#                                                                   'conv2d_28[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 1, 1, 256)   0           ['add_5[0][0]']
#
#  reshape_1 (Reshape)            (None, 256)          0           ['max_pooling2d_1[0][0]']
#
#  dense_14 (Dense)               (None, 256)          65792       ['reshape_1[0][0]']
#
#  dense_15 (Dense)               (None, 256)          65792       ['dense_14[0][0]']
#
#  dense_16 (Dense)               (None, 256)          65792       ['dense_15[0][0]']
#
#  dense_17 (Dense)               (None, 256)          65792       ['dense_16[0][0]']
#
#  dense_18 (Dense)               (None, 35)           8995        ['dense_17[0][0]']
#
# ==================================================================================================
# Total params: 1,059,363
# Trainable params: 1,059,363
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 62772/62772 [==============================] - 539s 9ms/step - loss: 4.7352 - soft_acc: 0.2400 - val_loss: 1.2615 - val_soft_acc: 0.3609
# 123/123 [==============================] - 10s 74ms/step - loss: 1.2615 - soft_acc: 0.3610
# [1.2614752054214478, 0.3609530031681061]
# None
# 123/123 [==============================] - 9s 75ms/step - loss: 1.2615 - soft_acc: 0.3610
# [1.2614752054214478, 0.3609530031681061]
# 100%|██████████| 1/1 [00:27<00:00, 27.56s/it]
# Epoch: 0
# 	 Training Loss: 1.45	 Training Accuracy: 0.39
# 	 Validation Loss: 1.21	 Validation Accuracy: 0.47
# Saving model checkpoint to /home/daniel/PycharmProjects/kreuzer-skarke-ML/data/saved_models/invariantmlp_original.pt for epoch 0
# Epoch Loss: 0.99	 Epoch Accuracy: 0.61
# 0.6124633617943163
# Epoch Loss: 0.99	 Epoch Accuracy: 0.61
# [0]	train-Regression-accuracy:0.00000	train-Tweedie-Loss:48.75289	dtest-Regression-accuracy:0.00000	dtest-Tweedie-Loss:48.57562
# Saving final model checkpoint to /home/daniel/PycharmProjects/kreuzer-skarke-ML/data/saved_models/xgb_original.json for 1 boosting rounds(number of estimators)
# Saving results as a csv in  /home/daniel/PycharmProjects/kreuzer-skarke-ML/data/saved_results/xgb_original.csv
# The accuracy on the test set is  0.0
# None
# The accuracy on the test set is  0.0
# (None, 52, 52, 1)
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 52, 52, 1)]  0           []
#
#  patches (Patches)              (None, None, 16)     0           ['input_9[0][0]']
#
#  patch_encoder (PatchEncoder)   (None, 169, 64)      11904       ['patches[0][0]']
#
#  layer_normalization (LayerNorm  (None, 169, 64)     128         ['patch_encoder[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 169, 64)     66368       ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  add_6 (Add)                    (None, 169, 64)      0           ['multi_head_attention[0][0]',
#                                                                   'patch_encoder[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 169, 64)     128         ['add_6[0][0]']
#  rmalization)
#
#  dense_20 (Dense)               (None, 169, 128)     8320        ['layer_normalization_1[0][0]']
#
#  dropout (Dropout)              (None, 169, 128)     0           ['dense_20[0][0]']
#
#  dense_21 (Dense)               (None, 169, 64)      8256        ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 169, 64)      0           ['dense_21[0][0]']
#
#  add_7 (Add)                    (None, 169, 64)      0           ['dropout_1[0][0]',
#                                                                   'add_6[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 169, 64)     128         ['add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 169, 64)     66368       ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  add_8 (Add)                    (None, 169, 64)      0           ['multi_head_attention_1[0][0]',
#                                                                   'add_7[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 169, 64)     128         ['add_8[0][0]']
#  rmalization)
#
#  dense_22 (Dense)               (None, 169, 128)     8320        ['layer_normalization_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 169, 128)     0           ['dense_22[0][0]']
#
#  dense_23 (Dense)               (None, 169, 64)      8256        ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 169, 64)      0           ['dense_23[0][0]']
#
#  add_9 (Add)                    (None, 169, 64)      0           ['dropout_3[0][0]',
#                                                                   'add_8[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 169, 64)     128         ['add_9[0][0]']
#  rmalization)
#
#  flatten_3 (Flatten)            (None, 10816)        0           ['layer_normalization_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 10816)        0           ['flatten_3[0][0]']
#
#  dense_24 (Dense)               (None, 4)            43268       ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 4)            0           ['dense_24[0][0]']
#
#  dense_25 (Dense)               (None, 2)            10          ['dropout_5[0][0]']
#
#  dropout_6 (Dropout)            (None, 2)            0           ['dense_25[0][0]']
#
#  dense_26 (Dense)               (None, 45)           135         ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 221,845
# Trainable params: 221,845
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 221/221 [==============================] - ETA: 0s - loss: 255.2733 - soft_acc: 0.0073WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 221/221 [==============================] - 241s 1s/step - loss: 255.2733 - soft_acc: 0.0073 - val_loss: 153.3671 - val_soft_acc: 0.0000e+00
# 491/491 [==============================] - 22s 45ms/step - loss: 151.2676 - soft_acc: 0.0000e+00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 5
#       3     model_instance = model(dataset)
#       4     model_instance.train(num_epochs=1)
# ----> 5     print(model_instance.get_accuracy())
#       6     all_accuracies += [model_instance.get_accuracy()]
#       8 print(f'All accuracies: {all_accuracies}')
#
# File ~/PycharmProjects/kreuzer-skarke-ML/src/models/vision_transformer.py:276, in VisionT.get_accuracy(self)
#     274 def get_accuracy(self):
#     275     #self.model.load_weights(self.saved_model_path)
# --> 276     _, accuracy, top_5_accuracy = self.model.evaluate(self.X['test'], self.y['test'])
#     277     print(f"Test accuracy: {round(accuracy * 100, 2)}%")
#     278     print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
#
# ValueError: not enough values to unpack (expected 3, got 2)
